# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('Titanic-Dataset.csv')
women=df[df['Sex']=='female']
men=df[df['Sex']=='male']
women_suvived=women[women['Survived']==1]
men_survived=men[men['Survived']==1]
women_not_survived=women[women['Survived']==0]
men_not_survived=men[men['Survived']==0]
women_survived1=df[(df['Sex']=='female') & (df['Survived']==1)] #composite filter
men_survived1=df[(df['Sex']=='male') & (df['Survived']==1)] #composite filter
women_not_survived1=df[(df['Sex']=='female') & (df['Survived']==0)] #composite filter
men_not_survived1=df[(df['Sex']=='male') & (df['Survived']==0)] #composite filter
print(women_not_survived1.shape[0])
# Out:
# 81

# %%
pd.DataFrame(df.value_counts()) #outputs similar to group by in SQL
#pd.DataFrame(df[['Sex','Survived']].value_counts())
# Out:
#                                                                                                                                               count
# PassengerId Survived Pclass Name                                               Sex    Age  SibSp Parch Ticket   Fare    Cabin       Embarked
# 2           1        1      Cumings, Mrs. John Bradley (Florence Briggs Tha... female 38.0 1     0     PC 17599 71.2833 C85         C             1
# 4           1        1      Futrelle, Mrs. Jacques Heath (Lily May Peel)       female 35.0 1     0     113803   53.1000 C123        S             1
# 7           0        1      McCarthy, Mr. Timothy J                            male   54.0 0     0     17463    51.8625 E46         S             1
# 11          1        3      Sandstrom, Miss. Marguerite Rut                    female 4.0  1     1     PP 9549  16.7000 G6          S             1
# ...

# %%
pd.crosstab(df['Sex'],df['Survived'])
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
pd.crosstab(df['Survived'],df['Sex'])
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
women=df[df['Sex']=='female']
women_suvived=women[women['Survived']==1]
women_not_survived=women[women['Survived']==0]
women_survived=df[(df['Sex']=='female') & (df['Survived']==1) & (df['Embarked']=='Q')] #composite filter with partial braces
women_survived=df[(df['Sex']=='female') & (df['Survived']==1)]
women_survived['Embarked'].value_counts()
# Out:
# Embarked
# S    140
# C     64
# Q     27
# Name: count, dtype: int64

# %%
sns.histplot(women_survived.Age,bins=10,label='Women Survived',kde=True)
plt.legend()
sns.displot(women_not_survived.Age,bins=10,label='Women Not Survived',kde=True)
plt.legend()

# %%
sns.histplot(men_survived.Age,bins=10,label='Men Survived',kde=True)
plt.legend()
sns.displot(men_not_survived.Age,bins=10,label='Men Not Survived',kde=True)
plt.legend()

# %%
#Histogram gets affected by bins values
#KDE does not get affected by bins values
